# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 3</b>
#
# Теперь всё получилось хорошо. Я принимаю проект и желаю удачи в прохождении курса!
#
# Для изучения дополнительной информации по Tableau могу посоветовать [этот марафон](https://tableau.pro/m00). В нем есть много полезных советов, ссылок на книги и дополнительные ресурсы.
#
# [Плейлист с решением задач марафона](https://www.youtube.com/playlist?list=PLgG9iJlSBmTcMvZqpKTPDrNC_zq1xKOxQ).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2</b>
#
# Добрый день. Спасибо за доделанную работу. Поправить осталось только график с распределением числа выступлений:
#
# * поле author_id надо использовать не только для подписей, но и для расчета:
#
# ![image.png](attachment:image.png)
#
# * на оси y нас просят показать проценты;
# * по оси X сейчас применена сортировка, ее надо убрать, так как числа идут не по порядку.
#
# В результате получится так:
#
# ![image-2.png](attachment:image-2.png)
# </div>

# %% [markdown]
# Привет, Валерий.
#
# Меня зовут Людмила, и я буду проводить ревью твоего проекта.
#
# Предлагаю перейти на «ты», если не против)
#
# Но если это не удобно — дай знать, и мы перейдем на «вы». Моя главная задача — не находить сделанные тобою ошибки, а передать свой опыт и помочь тебе стать аналитиком данных.
#
# Мои комментарии будут в ячейках «Комментарий ревьюера».
#
# ---
# <div class="alert alert-block alert-danger">
#
# Критическое замечание, которые следует исправить.
# </div>
#
# <div class="alert alert-block alert-warning">
#
# Замечание\совет на будущее.
# </div>
#
# <div class="alert alert-block alert-success">
#
# Когда всё сделано правильно.
# </div>
#
# ---
#
# Укажи, пожалуйста, изменения в проект, которые ты внесешь, в своем комментарии. Будет удобно, если ты поместишь его
#
# <div class="alert alert-info">
#
# в такую ячейку
# </div>
#
# Давай при работе с проектом мы будем общаться с тобой в диалоге, поэтому не удаляй мои комментарии, это поможет мне сделать повторную  проверку проекта быстрее.
# ___

# %% [markdown]
# **Ссылка на проект исследования истории TED-конференций с помощью Tableau. Выполнил Гришин Валерий Васильевич**

# %% [markdown]
# https://public.tableau.com/views/20231111_project_tedconf_GrishinVV_v_1/TED-?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера:</b>
#
# **История выступлений**
#
# * Ты использовал правильные способы для объединения таблиц.
# * На дашборде представлены все нужные визуализации.
# * Ты выделяешь топ тематик выступлений, и графики получаются не перегруженными информацией.
# * Здорово, что ты подписываешь секторы графиков, так они становятся нагляднее.
# * Настроен Action для фильтрации графиков.
# * Хорошо, что ты меняешь автоматически сформированные наименования во всплывающих подсказках.
# * Есть выводы с ответами на вопросы задания.
#
# **Тематики выступлений**
#
# * На круговой диаграмме показано топ-10 тем, остальные объединены в категорию "Другие", настроена всплывающая подсказка с гистограммами длительности и просмотров.
# * Ты правильно выделяешь топ-3 страны.
# * Корректно созданы новые вычисляемые поля и графики на их основе, диаграммы размаха отсортированы по медиане.
#
# **Авторы выступлений**
#
# * Правильно настроена визуализация "Области деятельности авторов".
# * Таблицы "Авторы по числу выступлений" и "Выступления и число просмотров" отсортированы по убыванию.
# * Настроены оба Action.
#
# **Свободная тема**
#
# * Ты выбрал интересную тему для дополнительного дашборда, и графики получились очень наглядные.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Комментарий ревьюера:</b>
#
# **История выступлений**
#
# * Сейчас для просмотра доступны все листы проекта, но в задании нас просят опубликовать только презентацию. Лучше скорректировать дашборды так, чтобы доступ был только к презентации.
#
# **Тематики выступлений**
#
# * На график связи длительности с просмотрами для наглядности можно добавить линию тренда:
#
# ![image.png](attachment:image.png)
#
# **Авторы выступлений**
#
# * Логичнее расположить таблицу с авторами выше таблицы с выступлениями: так будет удобно выбрав автора, просмотреть его выступления ниже.
# * Можно добавить подписи значений в столбцах графика с распределением числа выступлений, чтобы необязательно было пользоваться всплывающей подсказкой.
#
# **Свободная тема**
#
# * Так как в названии дашборда указаны только 2019-2021 гг., фильтр по годам можно убрать.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b>
#
# **История выступлений**
#
# * В задании нас просят настроить фильтр, который исключит все выступления до найденного порогового года на уровне источника данных. То есть данные до порогового года не должны быть доступны пользователю.
# * В презентации в качестве порогового выбран 2008 год, но рост числа выступлений заметен уже после 2001 года, поэтому границу стоит сдвинуть.
# * Один из секторов графиков сейчас подписан "за период с 2019 по 2021 годы". Лучше поправить это название на "Другие", так как у нас другой период на дашборде.
#
# **Тематики выступлений**
#
# * В таблице "Тематики и страны" нас просят использовать другой способ сортировки: по убыванию числа просмотров по горизонтальной и вертикальной оси.
# * Здесь же для разбивки по цвету стоит использовать такой же расчет, как для текста:
#
# ![image.png](attachment:image.png)
#
# * Во всплывающей подсказке диаграмм размаха неверно отображается имя автора. Оно указано в поле speaker_name.
#
# ![image-2.png](attachment:image-2.png)
#
# * Также во всплывающую подсказку диаграмм размаха надо добавить название выступления.
# * В выводы надо добавить названия самого смешного выступления и выступления, которому аплодировали больше всего.
#
# **Авторы выступлений**
#
# * На оси Y графика "Распределение числа выступлений" надо посчитать число авторов, то есть их id.
# * В таблице с выступлениями нас просят сделать другой порядок столбцов: название выступления, описание выступления, конференция, на которой проводилось выступление, число просмотров. Так после сортировки выступление с самым большим числом просмотров будет сверху.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Итоговый комментарий ревьюера:</b>
#
# Благодарю тебя за выполнение проекта. Вижу ты постарался, когда работал над ним. У тебя получилась логичная презентация, и ты ответил на все вопросы задания. Однако, в проекте есть несколько замечаний, которые надо исправить:
#
# * изменить фильтрацию данных по годам;
# * дополнить всплывающие подсказки;
# * скорректировать таблицу "Тематики и страны" и диаграммы размаха;
# * скорректировать график "Распределение числа выступлений" и таблицу с выступлениями.
#
# Жду проект после доработки. Уверена, ты справишься. 💪
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Людмила, Добрый день!
#
#     Спасибо за быстрый ответ и Ваше очень информативное и полезное ревью моего проекта.
#
#     Я доработал проект только в тех пунктах где у Вас имелись критические замечания по нему и не внося больше никаких изменений направляю его на повторное ревью.
#
#     Надеюсь на положительную оценку моей работы.
# </div>

# %% [markdown]
# https://public.tableau.com/views/20231112_project_tedconf_GrishinVV_v_2/TED-?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link

# %% [markdown]
# <div class="alert alert-info">
# Людмила, Добрый день!
#
#     Спасибо за быстрый ответ!
#
#     Исправил график "Распределений числа выступленни".
#
#     Жду Вашего решения.
# </div>

# %% [markdown]
# https://public.tableau.com/views/20231112_project_tedconf_GrishinVV_v_3/TED-?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link
